# %% [markdown]
# <a href="https://colab.research.google.com/github/strzelnat/machine_learning_basics/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('test')
# Out:
# test
